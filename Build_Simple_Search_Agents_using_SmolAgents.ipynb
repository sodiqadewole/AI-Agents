# %% [markdown]
# <a href="https://colab.research.google.com/github/sodiqadewole/AI-Agents/blob/main/Build_Simple_Search_Agents_using_SmolAgents.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install 'smolagents[toolkit]'

# %%
# Login to HF
from huggingface_hub import notebook_login

notebook_login()

# %%
from smolagents import CodeAgent, InferenceClientModel

# Initialize a model using HF Inference API
model = InferenceClientModel()

# Create an agent with no tools
agent = CodeAgent(tools=[], model=model)

# Run the agent with a task
result = agent.run("Calculate the sum of numbers from 1 to 10")
print(result)
# Out:
# ╭──────────────────────────────────────────────────── New run ────────────────────────────────────────────────────╮
# │                                                                                                                 │
# │ Calculate the sum of numbers from 1 to 10                                                                       │
# │                                                                                                                 │
# ╰─ InferenceClientModel - Qwen/Qwen2.5-Coder-32B-Instruct ────────────────────────────────────────────────────────╯
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ Step 1 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#  ─ Executing parsed code: ────────────────────────────────────────────────────────────────────────────────────────
#   numbers = range(1, 11)
#   total_sum = sum(numbers)
#   final_answer(total_sum)
# ...

# %% [markdown]
# #### Adding Tools

# %%
from smolagents import CodeAgent, InferenceClientModel, DuckDuckGoSearchTool

model = InferenceClientModel()
search = DuckDuckGoSearchTool()

agent = CodeAgent(tools=[search], model=model)

result = agent.run("What is the capital of Afghanistan?")
print(result)
# Out:
# ╭──────────────────────────────────────────────────── New run ────────────────────────────────────────────────────╮
# │                                                                                                                 │
# │ What is the capital of Afghanistan?                                                                             │
# │                                                                                                                 │
# ╰─ InferenceClientModel - Qwen/Qwen2.5-Coder-32B-Instruct ────────────────────────────────────────────────────────╯
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ Step 1 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#  ─ Executing parsed code: ────────────────────────────────────────────────────────────────────────────────────────
#   capital_query = "capital of Afghanistan"
#   capital_info = web_search(capital_query)
#   print(capital_info)
# ...

# %% [markdown]
# #### Using a Different Model

# %%
# Use a specific model from HF
from smolagents import InferenceClientModel

model = InferenceClientModel(model_id="meta-llama/Meta-Llama-3-70B-Instruct")

search = DuckDuckGoSearchTool()

# Create an agent with no tools
agent = CodeAgent(tools=[search], model=model)

# Run the agent with a task
result = agent.run("Who is the current President of Romania")
print(result)
# Out:
# ╭──────────────────────────────────────────────────── New run ────────────────────────────────────────────────────╮
# │                                                                                                                 │
# │ Who is the current President of Romania                                                                         │
# │                                                                                                                 │
# ╰─ InferenceClientModel - meta-llama/Meta-Llama-3-70B-Instruct ───────────────────────────────────────────────────╯
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ Step 1 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#  ─ Executing parsed code: ────────────────────────────────────────────────────────────────────────────────────────
#   current_president = web_search(query="Current President of Romania")
#   print("Current President of Romania:", current_president)
# ...

# %% [markdown]
# #### Using LiteLLM

# %%
# !pip install "smolagents[litellm]"

# %%
# NOTE: REQUIRES ADDING GPT TOKEN TO THE ENVIRONMENT VARIABLE
from smolagents import LiteLLMModel

model = LiteLLMModel(model_id='gpt-4')

search = DuckDuckGoSearchTool()

# Create an agent with no tools
agent = CodeAgent(tools=[search], model=model)

# Run the agent with a task
result = agent.run("Who is the current President of Indonesia")
print(result)

# %% [markdown]
# #### Using Local Transformer Model

# %%
# Using local models
from smolagents import TransformersModel
model = TransformersModel(model_id='meta-llama/Llama-2-7b-chat-hf')
